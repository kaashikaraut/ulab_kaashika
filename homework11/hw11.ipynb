# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# Your comment here
#I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
# Your code here (WITHOUT NUMPY! or any other modules/libraries/packages)
def orbital_period(a):
    #calculate orbital period based on formula
    return (a**3)**0.5

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
# Your code here
planet_a = 0.5
planet_b = 1.0
planet_c = 1.5

T_a = orbital_period(planet_a)
T_b = orbital_period(planet_b)
T_c = orbital_period(planet_c)

print(f"The orbital period for planet A (a = {planet_a} AU) is {T_a:.2f} years.")
print(f"The orbital period for planet B (a = {planet_b} AU) is {T_b:.2f} years.")
print(f"The orbital period for planet C (a = {planet_c} AU) is {T_c:.2f} years.")
# Out:
# The orbital period for planet A (a = 0.5 AU) is 0.35 years.
# The orbital period for planet B (a = 1.0 AU) is 1.00 years.
# The orbital period for planet C (a = 1.5 AU) is 1.84 years.

# %% [markdown]
# Import `numpy` in the cell below.

# %%
# Your code here
import numpy as np

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# Your comment (2 sentences)
#Once, because when you call it at the beginning, it can be used the whole time. This is very useful because it is a helpful library.

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
# Your code here
def orbital_period_numpy(a):
    #calculate orbital period using numpy
    return np.sqrt(np.power(a, 3))

# %% [markdown]
# Import the `time` package in the cell below.

# %%
# Your code here
import time

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
# Your code here
#original function
start_time = time.time()
result_original = orbital_period(5)
end_time = time.time()
time_original = end_time - start_time

#numpy function
start_time = time.time()
result_numpy = orbital_period_numpy(5)
end_time = time.time()
time_numpy = end_time - start_time

# Output the results and the time taken by each function
print(f"Original function: {result_original:.2f} years")
print(f"Original function time: {time_original:.6f} seconds")
print(f"Numpy function: {result_numpy:.2f} years")
print(f"Numpy function time: {time_numpy:.6f} seconds")
# Out:
# Original function: 11.18 years
# Original function time: 0.000532 seconds
# Numpy function: 11.18 years
# Numpy function time: 0.000000 seconds

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Your comment here
#the numpy function is faster. this is likely because numpy functions are optimized for speed.

# %% [markdown]
# Define a **list** in the cell below that contains a least 1,000,000 semi-major axis values.

# %%
# Your code here
semi_major_axes = [i* 0.1 for i in range(1, 1000001)]
#this increases the increments by 0.1

# %% [markdown]
# With a **for** loop. Time each of your functions again with this new list.

# %%
# Your code here
#og function
start_time = time.time()
for a in semi_major_axes:
    result_original = orbital_period(a)
end_time = time.time()
time_original = end_time - start_time

# Time the numpy-based function with the for loop
start_time = time.time()
for a in semi_major_axes:
    result_numpy = orbital_period_numpy(a)
end_time = time.time()
time_numpy = end_time - start_time

# Output the results and the time taken by each function
print(f"Original function execution time: {time_original:.6f} seconds")
print(f"Numpy function execution time: {time_numpy:.6f} seconds")
# Out:
# Original function execution time: 5.339957 seconds
# Numpy function execution time: 4.772742 seconds

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Your code here
#again, numpy was faster than the original function, probably because numpy is designed for these purposes

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
# Your code here
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]
for i in range(len(temperatures)):
    if temperatures[i] < 350:
        print(f"planet {i+1}: radius = {radii[i]} Earth radii, Temperature = {temperatures[i]} K")
#loop through the range of temperatures, if less than 350K then print
# Out:
# planet 1: radius = 1.2 Earth radii, Temperature = 300 K
# planet 4: radius = 2.0 Earth radii, Temperature = 280 K

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
# Your code here
first_three_radii = radii[:3]
print("Radii of the first three planets:", first_three_radii)
# Out:
# Radii of the first three planets: [1.2, 0.8, 1.5]

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
# Your code here
planets = dict(zip(radii, temperatures))
#assigns radii and temperature to planets
print("Exoplanet data:", planets)
# Out:
# Exoplanet data: {1.2: 300, 0.8: 400, 1.5: 350, 2.0: 280, 1.0: 500, 0.6: 450}

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
# Your code here

planet_names = ['Planet A', 'Planet B', 'Planet C', 'Planet D', 'Planet E', 'Planet F']

#planet names as keys and radius, temperatureas values
planets = {planet_names[i]: (radii[i], temperatures[i]) for i in range(len(planet_names))}
print("Exoplanet data with names:", planets)
# Out:
# Exoplanet data with names: {'Planet A': (1.2, 300), 'Planet B': (0.8, 400), 'Planet C': (1.5, 350), 'Planet D': (2.0, 280), 'Planet E': (1.0, 500), 'Planet F': (0.6, 450)}

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
# Your code here
filtered_planets = {name: data for name, data in planets.items() if 1.0 <= data[0] <= 2.0}
print("Filtered planets (1.0 to 2.0 Earth radii):", filtered_planets)
# Out:
# Filtered planets (1.0 to 2.0 Earth radii): {'Planet A': (1.2, 300), 'Planet C': (1.5, 350), 'Planet D': (2.0, 280), 'Planet E': (1.0, 500)}

# %% [markdown]
# ## 3 NumPy
# With your 1,000,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
# Your code here
semi_major_axes = [i* 0.1 for i in range(1, 1000001)]
semi_major_axes_array = np.array(semi_major_axes)

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
# Your code here
mean_value = np.mean(semi_major_axes_array)
median_value = np.median(semi_major_axes_array)
min_value = np.min(semi_major_axes_array)
max_value = np.max(semi_major_axes_array)
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Minimum: {min_value}")
print(f"Maximum: {max_value}")
# Out:
# Mean: 50000.05
# Median: 50000.05
# Minimum: 0.1
# Maximum: 100000.0

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
# Your code here
percentile_25 = np.percentile(semi_major_axes_array, 25)
percentile_75 = np.percentile(semi_major_axes_array, 75)
print(f"25th percentile: {percentile_25}")
print(f"75th percentile: {percentile_75}")

#the percentile function finds the percentile of the data for a given percentage
# Out:
# 25th percentile: 25000.075
# 75th percentile: 75000.025

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
# Your code here
planets_data = np.array([radii, temperatures])
print(planets_data)
# Out:
# [[  1.2   0.8   1.5   2.    1.    0.6]
#  [300.  400.  350.  280.  500.  450. ]]

# %% [markdown]
# Use a for loop to print the value on the second row, third column.

# %%
# Your code here
for i in range(planets_data.shape[1]):  #loop through columns
    if i == 2:  #3rd column
        print(planets_data[1, i])  #prints the value in the second row and third column
# Out:
# 350.0

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, third column.

# %%
# Your code here
print(planets_data[1, 2])
# Out:
# 350.0

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
# Your code here
import matplotlib.pyplot as plt

semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
orbital_periods = [a**(3/2) for a in semi_major_axes]

#scatter
plt.scatter(semi_major_axes, orbital_periods, label="Orbital Periods")
plt.xlabel("Semi-major Axis (AU)")
plt.ylabel("Orbital Period (years)")
plt.title("Orbital Periods of Exoplanets")
plt.legend()
plt.show()

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
# Your code here
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]
plt.bar(radii, temperatures, label="Equilibrium Temperatures", color='skyblue')
plt.xlabel("Planet Radii (Earth Radii)")
plt.ylabel("Equilibrium Temperature (Kelvin)")
plt.title("Equilibrium Temperatures vs. Radii")
plt.legend()
plt.show()

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizonatally).

# %%
# Your code here
#data
semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
orbital_periods = [a**(3/2) for a in semi_major_axes]
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]  # Planet radii (in Earth radii)
temperatures = [300, 400, 350, 280, 500, 450]  # Planet equilibrium temperatures (in Kelvin)


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
#scatterplot
ax1.scatter(semi_major_axes, orbital_periods, label="Orbital Periods", color='purple')
ax1.set_xlabel("Semi-major Axis (AU)")
ax1.set_ylabel("Orbital Period (years)")
ax1.set_title("Orbital Periods of Exoplanets")
ax1.legend()

#barplot
ax2.bar(radii, temperatures, label="Equilibrium Temperatures", color='skyblue')
ax2.set_xlabel("Planet Radii (Earth Radii)")
ax2.set_ylabel("Equilibrium Temperature (Kelvin)")
ax2.set_title("Equilibrium Temperatures vs. Radii")
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.

# %%
# Your code here
import kepler
from kepler import orbital_period

#test function
planet_a = 0.5  # AU
planet_b = 1.0  # AU
planet_c = 1.5  # AU

T_a = kepler_module.orbital_period(planet_a)
T_b = kepler_module.orbital_period(planet_b)
T_c = kepler_module.orbital_period(planet_c)

print(f"Orbital period for a = {planet_a} AU: {T_a} years")
print(f"Orbital period for a = {planet_b} AU: {T_b} years")
print(f"Orbital period for a = {planet_c} AU: {T_c} years")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[53], line 3
#       1 # Your code here
#       2 import kepler
# ----> 3 from kepler import orbital_period
#       5 #test function
#       6 planet_a = 0.5  # AU
#
# ImportError: cannot import name 'orbital_period' from 'kepler' (C:\Users\kaash_rosqmgh\ulab\ulab_2024\homework11\kepler.py)

# %%
import os
print(os.listdir())  # This lists all files in the current directory
import kepler
print(dir(kepler))
# Out:
# ['.ipynb_checkpoints', 'hw11.ipynb', 'kepler.py', '__pycache__']
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
#I have run into an issue with the module, where it is importing the module but the function is not able to be called. I tried troubleshooting it for a while, but nothing seemed to work.
