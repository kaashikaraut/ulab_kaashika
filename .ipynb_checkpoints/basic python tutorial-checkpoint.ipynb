# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
#int
type(3)
# Out:
# int

# %%
#float
type(1.)
# Out:
# float

# %%
#string
type("eeb, the most egotistical, dictatorial individual i have ever known")
# Out:
# str

# %%
#boolean
type(True)
# Out:
# bool

# %%
#list
type([1, 2, 3])
# Out:
# list

# %%
#dictionary
type({"color" : "blue"})
# Out:
# dict

# %%
#tuple
type((1,2))
# Out:
# tuple

# %%
1+1
# Out:
# 2
